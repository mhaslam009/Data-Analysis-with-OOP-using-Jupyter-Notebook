# %% [markdown]
# <h1>Python Problems</h1>

# %% [markdown]
# <h2>Grades Calculator</h2>
# <p>Create a program that takes a list of student names and their scores as input. Calculate and print the grades for each student based on the following criteria: A (90-100), B (80-89), C (70-79), D (60-69), F (below 60).</p>

# %%
"""
dict_students={}
print("------------------------------------------------------------")
for i in range(1,3): #5 students will enroll
    students=input(f"Enter {i}-Student Name:")
    grade=int(input("Enter his grade :"))
    dict_students[students]=grade
print(dict_students)

#assign grade:
for i_key, i_val in dict_students.items():
    if i_val < 60:
        print(f'The student {i_key} is considered fail with {i_val} marks')
    else:
        print(f'The student {i_key} is considered pass with {i_val} marks')

print("____________________________")

"""
# Out:
# '\ndict_students={}\nprint("------------------------------------------------------------")\nfor i in range(1,3): #5 students will enroll\n    students=input(f"Enter {i}-Student Name:")\n    grade=int(input("Enter his grade :"))\n    dict_students[students]=grade\nprint(dict_students)\n\n#assign grade:\nfor i_key, i_val in dict_students.items():\n    if i_val < 60:\n        print(f\'The student {i_key} is considered fail with {i_val} marks\')\n    else:\n        print(f\'The student {i_key} is considered pass with {i_val} marks\')\n\nprint("____________________________")\n\n'

# %% [markdown]
# <h2>Even and Odd Lists:</h2>
# <p>Write a program that takes a list of numbers as input. Separate the even and odd numbers into two different lists and print both lists.</p>

# %%
"""
inp_list=[]
how_many_num_you_want=int(input("How many numbers you want to input?"))
for i in range(how_many_num_you_want):
    ent_num=int(input("Enter Number:"))
    inp_list.append(ent_num)
print(inp_list)

#evaluate whether it is odd or even, simple method if divisible by 2 its even
for i in inp_list:
    if i%2==0:
        print(f"{i} is even")
    else:
        print(f"{i} is odd")
        
"""
# Out:
# '\ninp_list=[]\nhow_many_num_you_want=int(input("How many numbers you want to input?"))\nfor i in range(how_many_num_you_want):\n    ent_num=int(input("Enter Number:"))\n    inp_list.append(ent_num)\nprint(inp_list)\n\n#evaluate whether it is odd or even, simple method if divisible by 2 its even\nfor i in inp_list:\n    if i%2==0:\n        print(f"{i} is even")\n    else:\n        print(f"{i} is odd")\n        \n'

# %% [markdown]
# <h2>FizzBuzz</h2>
# <p>Write a program that prints numbers from 1 to 100. For multiples of 3, print "Fizz." For multiples of 5, print "Buzz." For numbers that are multiples of both 3 and 5, print "FizzBuzz."</p>

# %%
fizz_buzz_number=100
while fizz_buzz_number > 0:
    if fizz_buzz_number % 3 == 0:
        print("Fizz")
    if fizz_buzz_number % 5 == 0:
        print("Buzz")
    if fizz_buzz_number % 3 == 0 & fizz_buzz_number % 5 ==0:
        print("FizzBuzz")
    
    
    fizz_buzz_number=fizz_buzz_number-1
# Out:
# Buzz
# Fizz
# FizzBuzz
# Fizz
# FizzBuzz
# Buzz
# Fizz
# FizzBuzz
# Fizz
# Buzz
# FizzBuzz
# Fizz
# FizzBuzz
# Buzz
# Fizz
# FizzBuzz
# Fizz
# FizzBuzz
# Buzz
# Fizz
# FizzBuzz
# Fizz
# Buzz
# FizzBuzz
# Fizz
# FizzBuzz
# Buzz
# Fizz
# FizzBuzz
# Fizz
# FizzBuzz
# Buzz
# Fizz
# FizzBuzz
# Fizz
# Buzz
# FizzBuzz
# Fizz
# FizzBuzz
# Buzz
# Fizz
# FizzBuzz
# Fizz
# FizzBuzz
# Buzz
# Fizz
# FizzBuzz
# Fizz
# Buzz
# FizzBuzz
# Fizz
# FizzBuzz
# Buzz
# Fizz
# FizzBuzz
# Fizz
# FizzBuzz
# Buzz
# Fizz
# FizzBuzz
# Fizz
# Buzz
# FizzBuzz
# Fizz
# FizzBuzz
# Buzz
# Fizz
# FizzBuzz
# Fizz
# FizzBuzz
# Buzz
# Fizz
# FizzBuzz
# Fizz
# Buzz
# FizzBuzz
# Fizz
# FizzBuzz
# Buzz
# Fizz
# FizzBuzz
# Fizz
# FizzBuzz
# Buzz
# Fizz
# FizzBuzz

# %% [markdown]
# <h1>FUNCTION</h1>

# %%
#make a user_def function of subtracting two numbers

def subtract(num1, num2):
    sub=num1-num2
    return sub

n1=10
n2=5
subtracted_numbers=subtract(n1,n2)
print(subtracted_numbers)
# Out:
# 5

# %% [markdown]
# <h3>Difference between argument and parameter</h3>
# <p>In context of function, argument is the value which is passed in the noraml programming flow, but the parameter is the value when the function receives the value where you defined a fucntion</p>

# %%
#def greet(string): #string is parameter
#greet("Hello") #Hello is an argument

# %% [markdown]
# <h2>Function that do not return any value</h2>
# <p>In this mannaer the function has the job to take the parameters print out the result</p>

# %%
def print_message(message):
    """This function prints the provided message."""
    print(message) #it provided a message

result = print_message("Hello, world!")
print(result)  # Output: None
# Out:
# Hello, world!
# None

# %% [markdown]
# <h2>Error Handling</h2>

# %%
try:
    num1 = int(input("Enter a numerator: "))
    num2 = int(input("Enter a denominator: "))
    result = num1 / num2
    print(f"The result of {num1} / {num2} is {result}")
except ZeroDivisionError:
    print("Error: Division by zero is not allowed")
except ValueError:
    print("Error: Please enter valid integer values")
# Out:
# Enter a numerator: 23
# Enter a denominator: 22
# The result of 23 / 22 is 1.0454545454545454

# %% [markdown]
# <h1>OOP</h1>

# %%
"""
1)class is created named Car
2)Constructor is used with parameters filling in
3)With self we created attributes, one is self.make
4)create a method called start_engine() in which you passed class instance(self)
5)In method you can use class attributes
6)creating an object by using class
7)Calling method on object


"""

class Car: #1
    def __init__(self, make, model): #2
        
        #constructor is used when defining class
        #__init__ is the constructor
        #self is used with constructor
        #parameters are self, make, and model
        
        self.make = make #3
        self.model = model #3
    
    def start_engine(self): #start_engine()is a method that is definned inside class Car  #4
        print(f"The {self.make} {self.model}'s engine is starting.") #5
        #self.model and self.mode is an attribute
# Creating an object (instance) of the Car class
my_car = Car("Toyota", "Camry") #6

# Calling the start_engine method on the object
my_car.start_engine()#7
# Out:
# The Toyota Camry's engine is starting.

# %%
ia=32
print(type(ia))
# Out:
# <class 'int'>

# %%
import pandas as pd
duplicate_tags_df=pd.read_csv("E:\CAREER_DATA\data_files\\Lot 5 Tags.csv")
#print(duplicate_tags_df)
duplicate_tags_df.rename(columns={'Unnamed: 3': 'Serial_card'}, inplace=True)
#print(duplicate_tags_df)

serial_tags=duplicate_tags_df["Serial_card"]
print(serial_tags)

a=0        
while a<10000:
    #ask for card check
    ask_user=int(input("Enter a Tag: "))
    for i in serial_tags:
        if i==ask_user:
            print("DUPLICATE")
        else:
            
    a+=1
# Out:
#   File "C:\Users\HR Computers\AppData\Local\Temp\ipykernel_3712\2075133873.py", line 19
#     a+=1
#     ^
# IndentationError: expected an indented block

# %%
import pandas as pd

duplicate_tags_df = pd.read_csv("E:/CAREER_DATA/data_files/dup_final_file.csv")
duplicate_tags_df
# Out:
#    Files\tForm\tCard\tUser Unnamed: 1   Unnamed: 2  Unnamed: 3  Unnamed: 4
# 0                    B0067    W34 5:5  37318:14464         395  3731814464
# 1                    B0073    W34 5:5  37318:10880         173  3731810880
# 2                    B0075    W34 5:5  37318:10880         393  3731810880
# 3                    B0076    W34 5:5  37318:11392        1209  3731811392
# 4                    B0077    W34 5:5  37318:10880        1387  3731810880
# ..                     ...        ...          ...         ...         ...
# 88                   B0959    W34 5:5  37316:35712        2437  3731635712
# 89                   B0960    W34 5:5  37316:46976        2423  3731646976
# 90                   B0961    W34 5:5  37316:35712        2425  3731635712
# 91                   B0962    W34 5:5  37316:35712        2427  3731635712
# 92                   B0984    W34 5:5  37316:35712        1307  3731635712
#
# [93 rows x 5 columns]

# %%
import pandas as pd
list11=[235,241,287,293,395,521,529,533,719,
       723,1177,1905,1463,949,1203,1197,895,889,2023,
       2455,2425,2415]
duplicate_tags_df = pd.read_csv("E:/CAREER_DATA/data_files/dup_final_file.csv")
duplicate_tags_df.rename(columns={'Unnamed: 3': 'Serial_card'}, inplace=True)
serial_tags = duplicate_tags_df["Serial_card"]
print(serial_tags)

# Create a set to store unique values
unique_serial_tags = set()

# Iterate through serial_tags and add to the set
for tag in serial_tags:
    unique_serial_tags.add(tag)

while True:
    # Ask for card check
    ask_user = int(input("Enter a Tag (or 'exit' to quit): "))
    
    if ask_user == 'exit':
        break
    
    if ask_user in unique_serial_tags:
        print("DUPLICATE")
    else:
        print("Not duplicate")
# Out:
# 0      395
# 1      173
# 2      393
# 3     1209
# 4     1387
#       ...
# 88    2437
# 89    2423
# 90    2425
# 91    2427
# 92    1307
# Name: Serial_card, Length: 93, dtype: int64
# Enter a Tag (or 'exit' to quit): 375
# Not duplicate
# Enter a Tag (or 'exit' to quit): 455
# Not duplicate
# Enter a Tag (or 'exit' to quit): 239
# Not duplicate
# Enter a Tag (or 'exit' to quit): 953
# Not duplicate
# Enter a Tag (or 'exit' to quit): 2047
# Not duplicate
# Enter a Tag (or 'exit' to quit): 2015
# Not duplicate
# Enter a Tag (or 'exit' to quit): 959
# Not duplicate
# Enter a Tag (or 'exit' to quit): 1300
# DUPLICATE
# Enter a Tag (or 'exit' to quit): 19
# Not duplicate
# Enter a Tag (or 'exit' to quit): 965
# Not duplicate
# Enter a Tag (or 'exit' to quit): 961
# DUPLICATE
# Enter a Tag (or 'exit' to quit): 951
# Not duplicate
# Enter a Tag (or 'exit' to quit): 957
# DUPLICATE
# Enter a Tag (or 'exit' to quit): 2013
# Not duplicate
# Enter a Tag (or 'exit' to quit): 2057
# ...

# %%
list01 = [235, 241, 287, 293, 395, 521, 529, 533, 719,
          723, 1177, 1905, 1463, 949, 1203, 1197, 895, 889, 2023,
          2455, 2425, 2415]

# Create a set to store unique values
unique_serial_tags01 = set()

# Populate the set with unique values from list01
for tag in list01:
    unique_serial_tags01.add(tag)

while True:
    # Ask for card check
    ask_user = input("Enter a Tag (or 'exit' to quit): ")
    
    if ask_user == 'exit':
        break
    
    ask_user = int(ask_user)  # Convert user input to an integer
    
    if ask_user in unique_serial_tags01:
        print("DUPLICATE")
    else:
        print("Not duplicate")
# Out:
# Enter a Tag (or 'exit' to quit): 529
# DUPLICATE
# Enter a Tag (or 'exit' to quit): 255
# Not duplicate
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3712\2620624855.py in <module>
#      12 while True:
#      13     # Ask for card check
# ---> 14     ask_user = input("Enter a Tag (or 'exit' to quit): ")
#      15
#      16     if ask_user == 'exit':
#
# G:\DICE ANALYTICS\ANNACONDA SETUP\ANA\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# ...

# %%
import pandas as pd
duplicate_tags_df = pd.read_excel("C:\Users\HR Computers\Desktop\words files\\UNIVERSITY ABROAD.xlsx")
serial_tags = duplicate_tags_df["Serial_card"]
print(serial_tags)

# Create a set to store unique values
#unique_serial_tags = set()

# Iterate through serial_tags and add to the set
for tag in serial_tags:
    unique_serial_tags.add(tag)

while True:
    # Ask for card check
    ask_user = int(input("Enter a Tag (or 'exit' to quit): "))
    
    if ask_user == 'exit':
        break
    
    if ask_user in unique_serial_tags:
        print("DUPLICATE")
    else:
        print("Not duplicate")

# %%
import pandas as pd
links_list = pd.read_excel("C:\\Users\HR Computers\\Desktop\words files\\UNIVERSITY ABROAD.xlsx",
                          sheet_name="summer_intake")
#links_list

links = links_list["LINK"]
print(links)

# Create a set to store unique values
uni_links = set()

# Iterate through serial_tags and add to the set
for tag in links:
    uni_links.add(tag)

while True:
    # Ask for card check
    ask_user = int(input("Enter a Tag (or 'exit' to quit): "))
    
    if ask_user == 'exit':
        break
    
    if ask_user in uni_links:
        print("DUPLICATE")
    else:
        print("Not duplicate")
# Out:
# 0     https://www2.daad.de/deutschland/studienangebo...
# 1     https://www2.daad.de/deutschland/studienangebo...
# 2     https://www2.daad.de/deutschland/studienangebo...
# 3     https://www2.daad.de/deutschland/studienangebo...
# 4     https://www2.daad.de/deutschland/studienangebo...
# 5     https://www2.daad.de/deutschland/studienangebo...
# 6     https://www2.daad.de/deutschland/studienangebo...
# 7     https://www2.daad.de/deutschland/studienangebo...
# 8     https://www2.daad.de/deutschland/studienangebo...
# 9     https://www2.daad.de/deutschland/studienangebo...
# 10    https://www2.daad.de/deutschland/studienangebo...
# 11    https://www2.daad.de/deutschland/studienangebo...
# 12    https://www2.daad.de/deutschland/studienangebo...
# 13    https://www2.daad.de/deutschland/studienangebo...
# 14    https://www2.daad.de/deutschland/studienangebo...
# 15    https://www2.daad.de/deutschland/studienangebo...
# 16    https://www2.daad.de/deutschland/studienangebo...
# ...
