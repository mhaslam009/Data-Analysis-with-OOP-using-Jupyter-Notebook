# %% [markdown]
# <h1>Annotation on graph</h1>

# %%
#annotate data
climate_df=pd.read_csv(file_dir+"climate_change.csv",index_col=0)

x_values = [1, 2, 3, 4, 5]
y_values = [10, 15, 8, 12, 7]

plt.plot(x_values, y_values, marker='o')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Annotated Graph')

annotate_x = 3 
annotate_y = 8
annotation_text = 'Low point'


plt.annotate(annotation_text, xy=(annotate_x, annotate_y), xytext=(annotate_x + 2.2, annotate_y + 2),
             arrowprops={"arrowstyle":"->", "color":"red"}, fontsize=12, ha='right', color="red")
#1st arg. is the text you want to annotate on graph ->string
#2nd arg. is xy= which is setting the position to be pointed at which is along and y axis, its both elemnts is x and y axis->tuple
#3rd agr. is xytext= is setting the position in terms of x and y axis of a string that is annotated on graph->tuple
#4th arg. is arrowprops= is dictionory in which arrowstyle and its color is being defined->dict
#5th arg. is fontsize of text that is annoptated on graph->int
#6th arg. is ha= horizental algnment on xytext position, which might be right or left->str

plt.show()

# %%
#import data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob
import re

#import list of files

directory=r'E:\CAREER_DATA\data_files\data_visualization/*'
directory=glob.glob(directory)
print(directory)
list_of_files=[]

for i in directory:
    # Regular expression pattern to extract the file name
    pattern = r'\\([^\\]+)$'
    
    # Search for the pattern in the string
    match = re.search(pattern, i)

    if match:
        file_name_with_extension = match.group(1)
        list_of_files.append(file_name_with_extension)
        print("Extracted file name:", file_name_with_extension)
    else:
        print("File name not found.")
        
print("USE file_dir TO ACCESS DIRECTORY")
file_dir="E:\CAREER_DATA\data_files\data_visualization\\"
#file=input("Enter File Name:")
#achieved_file=pd.read_csv(file_dir+file,index_col=0)
# Out:
# ['E:\\CAREER_DATA\\data_files\\data_visualization\\austin_weather.csv', 'E:\\CAREER_DATA\\data_files\\data_visualization\\automobile_insurance.txt', 'E:\\CAREER_DATA\\data_files\\data_visualization\\climate_change.csv', 'E:\\CAREER_DATA\\data_files\\data_visualization\\countries-of-the-world.csv', 'E:\\CAREER_DATA\\data_files\\data_visualization\\daily_show_guest.txt', 'E:\\CAREER_DATA\\data_files\\data_visualization\\medals_by_country_2016.csv', 'E:\\CAREER_DATA\\data_files\\data_visualization\\mpg.csv', 'E:\\CAREER_DATA\\data_files\\data_visualization\\school_improvemnt_grants.txt', 'E:\\CAREER_DATA\\data_files\\data_visualization\\scorecard_tuition_2018.txt', 'E:\\CAREER_DATA\\data_files\\data_visualization\\seattle_weather.csv', 'E:\\CAREER_DATA\\data_files\\data_visualization\\student-alcohol-consumption.csv', 'E:\\CAREER_DATA\\data_files\\data_visualization\\summer2016.csv', 'E:\\CAREER_DATA\\data_files\\data_visualization\\us_housing_urban_development.txt', 'E:\\CAREER_DATA\\d
# ...

# %%
seattle_weather_df=pd.read_csv(file_dir+"seattle_weather.csv",index_col=0)
seattle_weather_df
# Out:
#                             NAME  DATE  MLY-CLDD-BASE45  MLY-CLDD-BASE50  \
# STATION
# USC00456295  PALMER 3 ESE, WA US     1             13.0              1.0
# USC00456295  PALMER 3 ESE, WA US     2             23.0              3.0
# USC00456295  PALMER 3 ESE, WA US     3             50.0             11.0
# USC00456295  PALMER 3 ESE, WA US     4            108.0             40.0
# USC00456295  PALMER 3 ESE, WA US     5            255.0            130.0
# ...                          ...   ...              ...              ...
# USC00454169          KENT, WA US     8            673.0            518.0
# USC00454169          KENT, WA US     9            493.0            344.0
# USC00454169          KENT, WA US    10            248.0            118.0
# USC00454169          KENT, WA US    11             78.0             19.0
# USC00454169          KENT, WA US    12             22.0              2.0
#
#              MLY-CLDD-BASE55  MLY-CLDD-BASE57  MLY-CLDD-BASE60  \
# STATION
# ...
